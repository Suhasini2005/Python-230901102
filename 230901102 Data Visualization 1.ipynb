# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,10])
ypoints = np.array([20,100])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x1116f01d0>]
# None

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,10])
ypoints = np.array([20,100])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x11172cf50>]
# None

# %%
xpoints = np.array([1,2,6,8])
ypoints = np.array([3,8,1,10])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x16466a1e0>]
# None
