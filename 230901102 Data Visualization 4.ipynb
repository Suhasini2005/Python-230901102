# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px
#seaborn package
xpoints=np.array([0,20,120,200])
ypoints=np.array([10,80,100,120,150,180,250])
print(sns.scatterplot(data=ypoints))
print(plt.show())
# Out:
# Axes(0.125,0.11;0.775x0.77)
# None

# %%
print(sns.barplot(data=ypoints))
print(plt.show())
# Out:
# Axes(0.125,0.11;0.775x0.77)
# None

# %%
x=np.array([1,2,6,8,12,14,20])
y=np.array([3,8,1,10,12,16,18])
fig=plt.figure(figsize=(12,8))
ax=plt.axes(prohection='3d')
plt_3d=ax.scatter3d(x,y)
plt.colorbar(plt_3d)
plt.show()
#plotly package
x=np.array([10,80,100,120,150,180,250])
fig=px.scatter(x)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 4
#       2 y=np.array([3,8,1,10,12,16,18])
#       3 fig=plt.figure(figsize=(12,8))
# ----> 4 ax=plt.axes(prohection='3d')
#       5 plt_3d=ax.scatter3d(x,y)
#       6 plt.colorbar(plt_3d)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:1330, in axes(arg, **kwargs)
#    1328 if arg is None:
#    1329     if pos is None:
# -> 1330         return fig.add_subplot(**kwargs)
#    1331     else:
#    1332         return fig.add_axes(pos, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/figure.py:710, in FigureBase.add_subplot(self, *args, **kwargs)
#     708         args = tuple(map(int, str(args[0])))
#     709     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 710     ax = projection_class(self, *args, **pkw)
#     711     key = (projection_class, pkw)
#     712 return self._add_axes_internal(ax, key)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:695, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     692 if yscale:
#     693     self.set_yscale(yscale)
# --> 695 self._internal_update(kwargs)
#     697 for name, axis in self._axis_map.items():
#     698     axis.callbacks._connect_picklable(
#     699         'units', self._unit_change_handler(name))
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/artist.py:1190, in Artist._update_props(self, props, errfmt)
#    1188             func = getattr(self, f"set_{k}", None)
#    1189             if not callable(func):
# -> 1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
#    1192             ret.append(func(v))
#    1193 if ret:
#
# AttributeError: Axes.set() got an unexpected keyword argument 'prohection'
